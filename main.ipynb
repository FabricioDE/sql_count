# %% [markdown]
# # Install dependencies during the first execution.

# %%
#!pip install pandas
#!pip install openpyxl

# %%
from utils.engine import Extract



file_dir = 'C:\\Users\\Fabricio Lucas\\Documents\\Codes\\sql_count'
name = 'sql_row_count'
ext = Extract(file_dir, name)

# %%
ext.extract()
